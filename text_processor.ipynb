# %% [markdown]
# Assignment 2

# %% [markdown]
# 1. Create a Doc object from the file owlcreek.txt

# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# %%
with open('/owlcreek.txt')as f:
  doc=nlp(f.read())

# %% [markdown]
# 2. How many tokens are contained in the file?

# %%
len(doc)
# Out:
# 4835

# %% [markdown]
# 3. How many sentences are contained in the file?

# %%
sentence_count = len(list(doc.sents))
sentence_count
# Out:
# 204

# %% [markdown]
# 4. Print the second sentence in the document

# %%
second_sentence= list(doc.sents)[1]
second_sentence
# Out:
# The man's hands were behind
# his back, the wrists bound with a cord.

# %% [markdown]
# 5. For each token in the sentence above, print its text, POS tag, dep tag and lemma.

# %%
for token in doc:
    print(f"Text: {token.text}, POS: {token.pos_}, Dep: {token.dep_}, Lemma: {token.lemma_}")
# Out:
# Text: AN, POS: DET, Dep: det, Lemma: an
# Text: OCCURRENCE, POS: NOUN, Dep: nmod, Lemma: occurrence
# Text: AT, POS: PROPN, Dep: compound, Lemma: AT
# Text: OWL, POS: PROPN, Dep: compound, Lemma: OWL
# Text: CREEK, POS: PROPN, Dep: compound, Lemma: CREEK
# Text: BRIDGE, POS: PROPN, Dep: appos, Lemma: BRIDGE
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: by, POS: ADP, Dep: prep, Lemma: by
# Text: Ambrose, POS: PROPN, Dep: compound, Lemma: Ambrose
# Text: Bierce, POS: PROPN, Dep: pobj, Lemma: Bierce
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: I, POS: PRON, Dep: conj, Lemma: I
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: A, POS: DET, Dep: det, Lemma: a
# Text: man, POS: NOUN, Dep: nsubj, Lemma: man
# Text: stood, POS: VERB, Dep: ROOT, Lemma: stand
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: railroad, POS: NOUN, Dep: compound, Lemma: railroad
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: northern, POS: ADJ, Dep: amod, Lemma: northern
# Text: Alabama, POS: PROPN, Dep: pobj, Lemma: Alabama
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: looking, POS: VERB, Dep: advcl, Lemma: look
# Text: down, POS: ADV, Dep: advmod, Lemma: down
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: into, POS: ADP, Dep: prep, Lemma: into
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: swift, POS: ADJ, Dep: amod, Lemma: swift
# Text: water, POS: NOUN, Dep: pobj, Lemma: water
# Text: twenty, POS: NUM, Dep: nummod, Lemma: twenty
# Text: feet, POS: NOUN, Dep: npadvmod, Lemma: foot
# Text: below, POS: ADV, Dep: advmod, Lemma: below
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: man, POS: NOUN, Dep: poss, Lemma: man
# Text: 's, POS: PART, Dep: case, Lemma: 's
# Text: hands, POS: NOUN, Dep: nsubj, Lemma: hand
# Text: were, POS: AUX, Dep: ROOT, Lemma: be
# Text: behind, POS: ADP, Dep: prep, Lemma: behind
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: back, POS: NOUN, Dep: pobj, Lemma: back
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: wrists, POS: NOUN, Dep: appos, Lemma: wrist
# Text: bound, POS: VERB, Dep: acl, Lemma: bind
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: cord, POS: NOUN, Dep: pobj, Lemma: cord
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: A, POS: DET, Dep: det, Lemma: a
# Text: rope, POS: NOUN, Dep: nsubj, Lemma: rope
# Text: closely, POS: ADV, Dep: advmod, Lemma: closely
# Text: encircled, POS: VERB, Dep: ROOT, Lemma: encircle
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: neck, POS: NOUN, Dep: dobj, Lemma: neck
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: It, POS: PRON, Dep: nsubjpass, Lemma: it
# Text: was, POS: AUX, Dep: auxpass, Lemma: be
# Text: attached, POS: VERB, Dep: ROOT, Lemma: attach
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: stout, POS: ADJ, Dep: amod, Lemma: stout
# Text: cross, POS: NOUN, Dep: pobj, Lemma: cross
# Text: -, POS: NOUN, Dep: pobj, Lemma: -
# Text: timber, POS: NOUN, Dep: pobj, Lemma: timber
# Text: above, POS: ADP, Dep: prep, Lemma: above
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: head, POS: NOUN, Dep: pobj, Lemma: head
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: slack, POS: NOUN, Dep: conj, Lemma: slack
# Text: fell, POS: VERB, Dep: advcl, Lemma: fall
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: level, POS: NOUN, Dep: pobj, Lemma: level
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: knees, POS: NOUN, Dep: pobj, Lemma: knee
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Some, POS: DET, Dep: det, Lemma: some
# Text: loose, POS: ADJ, Dep: amod, Lemma: loose
# Text: boards, POS: NOUN, Dep: nsubj, Lemma: board
# Text: laid, POS: VERB, Dep: acl, Lemma: lay
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: ties, POS: NOUN, Dep: pobj, Lemma: tie
# Text: supporting, POS: VERB, Dep: acl, Lemma: support
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: rails, POS: NOUN, Dep: dobj, Lemma: rail
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: railway, POS: NOUN, Dep: pobj, Lemma: railway
# Text: supplied, POS: VERB, Dep: ROOT, Lemma: supply
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: footing, POS: NOUN, Dep: dobj, Lemma: footing
# Text: for, POS: ADP, Dep: prep, Lemma: for
# Text: him, POS: PRON, Dep: pobj, Lemma: he
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: executioners, POS: NOUN, Dep: conj, Lemma: executioner
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text: private, POS: ADJ, Dep: amod, Lemma: private
# Text: soldiers, POS: NOUN, Dep: appos, Lemma: soldier
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: Federal, POS: PROPN, Dep: compound, Lemma: Federal
# Text: army, POS: NOUN, Dep: pobj, Lemma: army
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: directed, POS: VERB, Dep: advcl, Lemma: direct
# Text: by, POS: ADP, Dep: agent, Lemma: by
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: sergeant, POS: NOUN, Dep: pobj, Lemma: sergeant
# Text: who, POS: PRON, Dep: nsubj, Lemma: who
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: civil, POS: ADJ, Dep: amod, Lemma: civil
# Text: life, POS: NOUN, Dep: pobj, Lemma: life
# Text: may, POS: AUX, Dep: aux, Lemma: may
# Text: have, POS: AUX, Dep: aux, Lemma: have
# Text: been, POS: AUX, Dep: relcl, Lemma: be
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: deputy, POS: NOUN, Dep: compound, Lemma: deputy
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: sheriff, POS: NOUN, Dep: attr, Lemma: sheriff
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: At, POS: ADP, Dep: prep, Lemma: at
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: short, POS: ADJ, Dep: amod, Lemma: short
# Text: remove, POS: NOUN, Dep: pobj, Lemma: remove
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: same, POS: ADJ, Dep: amod, Lemma: same
# Text: temporary, POS: ADJ, Dep: amod, Lemma: temporary
# Text: platform, POS: NOUN, Dep: pobj, Lemma: platform
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: an, POS: DET, Dep: det, Lemma: an
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: officer, POS: NOUN, Dep: attr, Lemma: officer
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: uniform, POS: NOUN, Dep: pobj, Lemma: uniform
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: rank, POS: NOUN, Dep: pobj, Lemma: rank
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: armed, POS: VERB, Dep: acomp, Lemma: arm
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: captain, POS: NOUN, Dep: attr, Lemma: captain
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: A, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: sentinel, POS: NOUN, Dep: nsubj, Lemma: sentinel
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: each, POS: DET, Dep: det, Lemma: each
# Text: end, POS: NOUN, Dep: pobj, Lemma: end
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: stood, POS: VERB, Dep: ROOT, Lemma: stand
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: rifle, POS: NOUN, Dep: pobj, Lemma: rifle
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: position, POS: NOUN, Dep: pobj, Lemma: position
# Text: known, POS: VERB, Dep: acl, Lemma: know
# Text: as, POS: ADP, Dep: prep, Lemma: as
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: support, POS: NOUN, Dep: pobj, Lemma: support
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: that, POS: PRON, Dep: nsubj, Lemma: that
# Text: is, POS: AUX, Dep: parataxis, Lemma: be
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: say, POS: VERB, Dep: xcomp, Lemma: say
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: vertical, POS: ADJ, Dep: advcl, Lemma: vertical
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: front, POS: NOUN, Dep: pobj, Lemma: front
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: left, POS: VERB, Dep: amod, Lemma: leave
# Text: shoulder, POS: NOUN, Dep: pobj, Lemma: shoulder
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: hammer, POS: NOUN, Dep: compound, Lemma: hammer
# Text: resting, POS: NOUN, Dep: prep, Lemma: resting
# Text: on, POS: ADP, Dep: prep, Lemma: on
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: forearm, POS: NOUN, Dep: pobj, Lemma: forearm
# Text: thrown, POS: VERB, Dep: conj, Lemma: throw
# Text: straight, POS: ADV, Dep: advmod, Lemma: straight
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: across, POS: ADP, Dep: prep, Lemma: across
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: chest, POS: NOUN, Dep: pobj, Lemma: chest
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: formal, POS: ADJ, Dep: amod, Lemma: formal
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: unnatural, POS: ADJ, Dep: conj, Lemma: unnatural
# Text: position, POS: NOUN, Dep: appos, Lemma: position
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: enforcing, POS: VERB, Dep: advcl, Lemma: enforce
# Text: an, POS: DET, Dep: det, Lemma: an
# Text: erect, POS: ADJ, Dep: amod, Lemma: erect
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: carriage, POS: NOUN, Dep: dobj, Lemma: carriage
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: body, POS: NOUN, Dep: pobj, Lemma: body
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: It, POS: PRON, Dep: nsubj, Lemma: it
# Text: did, POS: AUX, Dep: aux, Lemma: do
# Text: not, POS: PART, Dep: neg, Lemma: not
# Text: appear, POS: VERB, Dep: ccomp, Lemma: appear
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: be, POS: AUX, Dep: xcomp, Lemma: be
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: duty, POS: NOUN, Dep: attr, Lemma: duty
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: these, POS: DET, Dep: det, Lemma: these
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: men, POS: NOUN, Dep: pobj, Lemma: man
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: know, POS: VERB, Dep: advcl, Lemma: know
# Text: what, POS: PRON, Dep: nsubj, Lemma: what
# Text: was, POS: AUX, Dep: aux, Lemma: be
# Text: occurring, POS: VERB, Dep: ccomp, Lemma: occur
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: center, POS: NOUN, Dep: pobj, Lemma: center
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: they, POS: PRON, Dep: nsubj, Lemma: they
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: merely, POS: ADV, Dep: advmod, Lemma: merely
# Text: blockaded, POS: VERB, Dep: ROOT, Lemma: blockade
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text: ends, POS: NOUN, Dep: dobj, Lemma: end
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: foot, POS: NOUN, Dep: compound, Lemma: foot
# Text: planking, POS: NOUN, Dep: pobj, Lemma: planking
# Text: that, POS: PRON, Dep: nsubj, Lemma: that
# Text: traversed, POS: VERB, Dep: relcl, Lemma: traverse
# Text: it, POS: PRON, Dep: dobj, Lemma: it
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: Beyond, POS: ADP, Dep: prep, Lemma: beyond
# Text: one, POS: NUM, Dep: pobj, Lemma: one
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: sentinels, POS: NOUN, Dep: pobj, Lemma: sentinel
# Text: nobody, POS: PRON, Dep: nsubj, Lemma: nobody
# Text: was, POS: AUX, Dep: relcl, Lemma: be
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: sight, POS: NOUN, Dep: pobj, Lemma: sight
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: railroad, POS: NOUN, Dep: nsubj, Lemma: railroad
# Text: ran, POS: VERB, Dep: ROOT, Lemma: run
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: straight, POS: ADV, Dep: advmod, Lemma: straight
# Text: away, POS: ADV, Dep: advmod, Lemma: away
# Text: into, POS: ADP, Dep: prep, Lemma: into
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: forest, POS: NOUN, Dep: pobj, Lemma: forest
# Text: for, POS: ADP, Dep: prep, Lemma: for
# Text: a, POS: DET, Dep: quantmod, Lemma: a
# Text: hundred, POS: NUM, Dep: nummod, Lemma: hundred
# Text: yards, POS: NOUN, Dep: pobj, Lemma: yard
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: then, POS: ADV, Dep: advmod, Lemma: then
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: curving, POS: NOUN, Dep: nsubjpass, Lemma: curving
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: was, POS: AUX, Dep: auxpass, Lemma: be
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: lost, POS: VERB, Dep: advcl, Lemma: lose
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: view, POS: NOUN, Dep: advcl, Lemma: view
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Doubtless, POS: PROPN, Dep: npadvmod, Lemma: Doubtless
# Text: there, POS: PRON, Dep: expl, Lemma: there
# Text: was, POS: VERB, Dep: ROOT, Lemma: be
# Text: an, POS: DET, Dep: det, Lemma: an
# Text: outpost, POS: NOUN, Dep: attr, Lemma: outpost
# Text: farther, POS: ADV, Dep: advmod, Lemma: far
# Text: along, POS: ADV, Dep: advmod, Lemma: along
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: other, POS: ADJ, Dep: amod, Lemma: other
# Text: bank, POS: NOUN, Dep: nsubj, Lemma: bank
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: stream, POS: NOUN, Dep: pobj, Lemma: stream
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: open, POS: ADJ, Dep: amod, Lemma: open
# Text: ground, POS: NOUN, Dep: attr, Lemma: ground
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: gentle, POS: ADJ, Dep: amod, Lemma: gentle
# Text: slope, POS: NOUN, Dep: appos, Lemma: slope
# Text: topped, POS: VERB, Dep: acl, Lemma: top
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: stockade, POS: NOUN, Dep: pobj, Lemma: stockade
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: vertical, POS: ADJ, Dep: amod, Lemma: vertical
# Text: tree, POS: NOUN, Dep: compound, Lemma: tree
# Text: trunks, POS: NOUN, Dep: pobj, Lemma: trunk
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: loopholed, POS: VERB, Dep: acl, Lemma: loophole
# Text: for, POS: ADP, Dep: prep, Lemma: for
# Text: rifles, POS: NOUN, Dep: pobj, Lemma: rifle
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: single, POS: ADJ, Dep: amod, Lemma: single
# Text: embrasure, POS: NOUN, Dep: pobj, Lemma: embrasure
# Text: through, POS: ADP, Dep: prep, Lemma: through
# Text: which, POS: PRON, Dep: pobj, Lemma: which
# Text: protruded, POS: VERB, Dep: relcl, Lemma: protrude
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: muzzle, POS: NOUN, Dep: dobj, Lemma: muzzle
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: brass, POS: NOUN, Dep: compound, Lemma: brass
# Text: cannon, POS: NOUN, Dep: pobj, Lemma: cannon
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: commanding, POS: VERB, Dep: acl, Lemma: command
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: dobj, Lemma: bridge
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Midway, POS: ADV, Dep: nsubj, Lemma: midway
# Text: up, POS: ADP, Dep: prep, Lemma: up
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: slope, POS: NOUN, Dep: dobj, Lemma: slope
# Text: between, POS: ADP, Dep: prep, Lemma: between
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: fort, POS: NOUN, Dep: conj, Lemma: fort
# Text: were, POS: AUX, Dep: ROOT, Lemma: be
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: spectators, POS: NOUN, Dep: attr, Lemma: spectator
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: single, POS: ADJ, Dep: amod, Lemma: single
# Text: company, POS: NOUN, Dep: appos, Lemma: company
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: infantry, POS: NOUN, Dep: pobj, Lemma: infantry
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: line, POS: NOUN, Dep: pobj, Lemma: line
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: parade, POS: NOUN, Dep: compound, Lemma: parade
# Text: rest, POS: NOUN, Dep: pobj, Lemma: rest
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: butts, POS: NOUN, Dep: dep, Lemma: butt
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: their, POS: PRON, Dep: poss, Lemma: their
# Text: rifles, POS: NOUN, Dep: pobj, Lemma: rifle
# Text: on, POS: ADP, Dep: prep, Lemma: on
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: ground, POS: NOUN, Dep: pobj, Lemma: ground
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: barrels, POS: NOUN, Dep: appos, Lemma: barrel
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: inclining, POS: VERB, Dep: acl, Lemma: incline
# Text: slightly, POS: ADV, Dep: advmod, Lemma: slightly
# Text: backward, POS: ADV, Dep: advmod, Lemma: backward
# Text: against, POS: ADP, Dep: prep, Lemma: against
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: right, POS: ADJ, Dep: amod, Lemma: right
# Text: shoulder, POS: NOUN, Dep: pobj, Lemma: shoulder
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: hands, POS: NOUN, Dep: conj, Lemma: hand
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: crossed, POS: VERB, Dep: acl, Lemma: cross
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: stock, POS: NOUN, Dep: pobj, Lemma: stock
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text: A, POS: DET, Dep: det, Lemma: a
# Text: lieutenant, POS: NOUN, Dep: nsubj, Lemma: lieutenant
# Text: stood, POS: VERB, Dep: ROOT, Lemma: stand
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: right, POS: NOUN, Dep: pobj, Lemma: right
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: line, POS: NOUN, Dep: pobj, Lemma: line
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: point, POS: NOUN, Dep: appos, Lemma: point
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: sword, POS: NOUN, Dep: pobj, Lemma: sword
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: ground, POS: NOUN, Dep: pobj, Lemma: ground
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: left, POS: ADJ, Dep: amod, Lemma: left
# Text: hand, POS: NOUN, Dep: nsubj, Lemma: hand
# Text: resting, POS: VERB, Dep: advcl, Lemma: rest
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: right, POS: NOUN, Dep: pobj, Lemma: right
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Excepting, POS: VERB, Dep: advcl, Lemma: except
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: group, POS: NOUN, Dep: dobj, Lemma: group
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: four, POS: NUM, Dep: pobj, Lemma: four
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: center, POS: NOUN, Dep: pobj, Lemma: center
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: not, POS: PART, Dep: neg, Lemma: not
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: man, POS: NOUN, Dep: nsubj, Lemma: man
# Text: moved, POS: VERB, Dep: ROOT, Lemma: move
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: company, POS: NOUN, Dep: nsubj, Lemma: company
# Text: faced, POS: VERB, Dep: ROOT, Lemma: face
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: dobj, Lemma: bridge
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: staring, POS: VERB, Dep: advcl, Lemma: stare
# Text: stonily, POS: ADV, Dep: advmod, Lemma: stonily
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: motionless, POS: NOUN, Dep: conj, Lemma: motionless
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: sentinels, POS: NOUN, Dep: nsubj, Lemma: sentinel
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: facing, POS: VERB, Dep: acl, Lemma: face
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: banks, POS: NOUN, Dep: dobj, Lemma: bank
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: stream, POS: NOUN, Dep: pobj, Lemma: stream
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: might, POS: AUX, Dep: aux, Lemma: might
# Text: have, POS: AUX, Dep: aux, Lemma: have
# Text: been, POS: AUX, Dep: ROOT, Lemma: be
# Text: statues, POS: NOUN, Dep: attr, Lemma: statue
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: adorn, POS: VERB, Dep: relcl, Lemma: adorn
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: dobj, Lemma: bridge
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: captain, POS: NOUN, Dep: nsubj, Lemma: captain
# Text: stood, POS: VERB, Dep: ROOT, Lemma: stand
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: folded, POS: ADJ, Dep: amod, Lemma: folded
# Text: arms, POS: NOUN, Dep: pobj, Lemma: arm
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: silent, POS: ADJ, Dep: amod, Lemma: silent
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: observing, POS: VERB, Dep: advcl, Lemma: observe
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: work, POS: NOUN, Dep: dobj, Lemma: work
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: subordinates, POS: NOUN, Dep: pobj, Lemma: subordinate
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: but, POS: CCONJ, Dep: cc, Lemma: but
# Text: making, POS: VERB, Dep: conj, Lemma: make
# Text: no, POS: DET, Dep: det, Lemma: no
# Text: sign, POS: NOUN, Dep: dobj, Lemma: sign
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text: Death, POS: NOUN, Dep: nsubj, Lemma: death
# Text: is, POS: AUX, Dep: ROOT, Lemma: be
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: dignitary, POS: NOUN, Dep: attr, Lemma: dignitary
# Text: who, POS: PRON, Dep: nsubjpass, Lemma: who
# Text: when, POS: SCONJ, Dep: advmod, Lemma: when
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: comes, POS: AUX, Dep: auxpass, Lemma: comes
# Text: announced, POS: VERB, Dep: relcl, Lemma: announce
# Text: is, POS: AUX, Dep: ccomp, Lemma: be
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: be, POS: AUX, Dep: auxpass, Lemma: be
# Text: received, POS: VERB, Dep: xcomp, Lemma: receive
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: formal, POS: ADJ, Dep: amod, Lemma: formal
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: manifestations, POS: NOUN, Dep: pobj, Lemma: manifestation
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: respect, POS: NOUN, Dep: pobj, Lemma: respect
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: even, POS: ADV, Dep: advmod, Lemma: even
# Text: by, POS: ADP, Dep: prep, Lemma: by
# Text: those, POS: PRON, Dep: pobj, Lemma: those
# Text: most, POS: ADV, Dep: advmod, Lemma: most
# Text: familiar, POS: ADJ, Dep: amod, Lemma: familiar
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: him, POS: PRON, Dep: pobj, Lemma: he
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: In, POS: ADP, Dep: prep, Lemma: in
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: code, POS: NOUN, Dep: pobj, Lemma: code
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: military, POS: ADJ, Dep: amod, Lemma: military
# Text: etiquette, POS: NOUN, Dep: compound, Lemma: etiquette
# Text: silence, POS: NOUN, Dep: pobj, Lemma: silence
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: fixity, POS: NOUN, Dep: conj, Lemma: fixity
# Text: are, POS: AUX, Dep: ROOT, Lemma: be
# Text: forms, POS: NOUN, Dep: attr, Lemma: form
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: deference, POS: NOUN, Dep: pobj, Lemma: deference
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: man, POS: NOUN, Dep: nsubj, Lemma: man
# Text: who, POS: PRON, Dep: nsubjpass, Lemma: who
# Text: was, POS: AUX, Dep: auxpass, Lemma: be
# Text: engaged, POS: VERB, Dep: relcl, Lemma: engage
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: being, POS: AUX, Dep: auxpass, Lemma: be
# Text: hanged, POS: VERB, Dep: pcomp, Lemma: hang
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: apparently, POS: ADV, Dep: advmod, Lemma: apparently
# Text: about, POS: ADV, Dep: advmod, Lemma: about
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: thirty, POS: NUM, Dep: compound, Lemma: thirty
# Text: -, POS: PUNCT, Dep: punct, Lemma: -
# Text: five, POS: NUM, Dep: nummod, Lemma: five
# Text: years, POS: NOUN, Dep: attr, Lemma: year
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: age, POS: NOUN, Dep: pobj, Lemma: age
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: civilian, POS: NOUN, Dep: attr, Lemma: civilian
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: if, POS: SCONJ, Dep: mark, Lemma: if
# Text: one, POS: PRON, Dep: nsubj, Lemma: one
# Text: might, POS: AUX, Dep: aux, Lemma: might
# Text: judge, POS: VERB, Dep: advcl, Lemma: judge
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: habit, POS: NOUN, Dep: pobj, Lemma: habit
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: which, POS: PRON, Dep: nsubj, Lemma: which
# Text: was, POS: AUX, Dep: relcl, Lemma: be
# Text: that, POS: PRON, Dep: attr, Lemma: that
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: planter, POS: NOUN, Dep: pobj, Lemma: planter
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: His, POS: PRON, Dep: poss, Lemma: his
# Text: features, POS: NOUN, Dep: nsubj, Lemma: feature
# Text: were, POS: AUX, Dep: ROOT, Lemma: be
# Text: good, POS: ADJ, Dep: acomp, Lemma: good
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: straight, POS: ADJ, Dep: amod, Lemma: straight
# Text: nose, POS: NOUN, Dep: appos, Lemma: nose
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: firm, POS: ADJ, Dep: amod, Lemma: firm
# Text: mouth, POS: NOUN, Dep: conj, Lemma: mouth
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: broad, POS: ADJ, Dep: amod, Lemma: broad
# Text: forehead, POS: NOUN, Dep: conj, Lemma: forehead
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: which, POS: PRON, Dep: pobj, Lemma: which
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: long, POS: ADJ, Dep: amod, Lemma: long
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: dark, POS: ADJ, Dep: amod, Lemma: dark
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: hair, POS: NOUN, Dep: nsubjpass, Lemma: hair
# Text: was, POS: AUX, Dep: auxpass, Lemma: be
# Text: combed, POS: VERB, Dep: relcl, Lemma: comb
# Text: straight, POS: ADV, Dep: advmod, Lemma: straight
# Text: back, POS: ADV, Dep: advmod, Lemma: back
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: falling, POS: VERB, Dep: advcl, Lemma: fall
# Text: behind, POS: ADP, Dep: prep, Lemma: behind
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: ears, POS: NOUN, Dep: pobj, Lemma: ear
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: collar, POS: NOUN, Dep: pobj, Lemma: collar
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: well, POS: ADV, Dep: advmod, Lemma: well
# Text: fitting, POS: ADJ, Dep: amod, Lemma: fitting
# Text: frock, POS: NOUN, Dep: compound, Lemma: frock
# Text: coat, POS: NOUN, Dep: pobj, Lemma: coat
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: wore, POS: VERB, Dep: ccomp, Lemma: wear
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: moustache, POS: NOUN, Dep: dobj, Lemma: moustache
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: pointed, POS: ADJ, Dep: amod, Lemma: pointed
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: beard, POS: NOUN, Dep: conj, Lemma: beard
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: but, POS: CCONJ, Dep: cc, Lemma: but
# Text: no, POS: DET, Dep: det, Lemma: no
# Text: whiskers, POS: NOUN, Dep: conj, Lemma: whisker
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: eyes, POS: NOUN, Dep: nsubj, Lemma: eye
# Text: were, POS: AUX, Dep: ROOT, Lemma: be
# Text: large, POS: ADJ, Dep: amod, Lemma: large
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: dark, POS: ADJ, Dep: conj, Lemma: dark
# Text: gray, POS: ADJ, Dep: acomp, Lemma: gray
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: had, POS: VERB, Dep: conj, Lemma: have
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: kindly, POS: ADV, Dep: amod, Lemma: kindly
# Text: expression, POS: NOUN, Dep: dobj, Lemma: expression
# Text: which, POS: PRON, Dep: dobj, Lemma: which
# Text: one, POS: PRON, Dep: nsubj, Lemma: one
# Text: would, POS: AUX, Dep: aux, Lemma: would
# Text: hardly, POS: ADV, Dep: advmod, Lemma: hardly
# Text: have, POS: AUX, Dep: aux, Lemma: have
# Text: expected, POS: VERB, Dep: relcl, Lemma: expect
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: one, POS: NUM, Dep: pobj, Lemma: one
# Text: whose, POS: DET, Dep: poss, Lemma: whose
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: neck, POS: NOUN, Dep: nsubj, Lemma: neck
# Text: was, POS: AUX, Dep: relcl, Lemma: be
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: hemp, POS: NOUN, Dep: pobj, Lemma: hemp
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Evidently, POS: ADV, Dep: advmod, Lemma: evidently
# Text: this, POS: PRON, Dep: nsubj, Lemma: this
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: no, POS: DET, Dep: det, Lemma: no
# Text: vulgar, POS: ADJ, Dep: amod, Lemma: vulgar
# Text: assassin, POS: NOUN, Dep: attr, Lemma: assassin
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: liberal, POS: ADJ, Dep: amod, Lemma: liberal
# Text: military, POS: ADJ, Dep: amod, Lemma: military
# Text: code, POS: NOUN, Dep: nsubj, Lemma: code
# Text: makes, POS: VERB, Dep: ROOT, Lemma: make
# Text: provision, POS: NOUN, Dep: dobj, Lemma: provision
# Text: for, POS: ADP, Dep: prep, Lemma: for
# Text: hanging, POS: VERB, Dep: pcomp, Lemma: hang
# Text: many, POS: ADJ, Dep: amod, Lemma: many
# Text: kinds, POS: NOUN, Dep: dobj, Lemma: kind
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: persons, POS: NOUN, Dep: pobj, Lemma: person
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: gentlemen, POS: NOUN, Dep: nsubjpass, Lemma: gentleman
# Text: are, POS: AUX, Dep: auxpass, Lemma: be
# Text: not, POS: PART, Dep: neg, Lemma: not
# Text: excluded, POS: VERB, Dep: conj, Lemma: exclude
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: preparations, POS: NOUN, Dep: nsubj, Lemma: preparation
# Text: being, POS: AUX, Dep: advcl, Lemma: be
# Text: complete, POS: ADJ, Dep: acomp, Lemma: complete
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text: private, POS: ADJ, Dep: amod, Lemma: private
# Text: soldiers, POS: NOUN, Dep: nsubj, Lemma: soldier
# Text: stepped, POS: VERB, Dep: ROOT, Lemma: step
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: aside, POS: ADV, Dep: advmod, Lemma: aside
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: each, POS: PRON, Dep: nsubj, Lemma: each
# Text: drew, POS: VERB, Dep: conj, Lemma: draw
# Text: away, POS: ADV, Dep: advmod, Lemma: away
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: plank, POS: NOUN, Dep: dobj, Lemma: plank
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: which, POS: PRON, Dep: pobj, Lemma: which
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: been, POS: AUX, Dep: aux, Lemma: be
# Text: standing, POS: VERB, Dep: relcl, Lemma: stand
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: sergeant, POS: NOUN, Dep: nsubj, Lemma: sergeant
# Text: turned, POS: VERB, Dep: ROOT, Lemma: turn
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: captain, POS: NOUN, Dep: pobj, Lemma: captain
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: saluted, POS: VERB, Dep: advcl, Lemma: salute
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: placed, POS: VERB, Dep: conj, Lemma: place
# Text: himself, POS: PRON, Dep: dobj, Lemma: himself
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: immediately, POS: ADV, Dep: advmod, Lemma: immediately
# Text: behind, POS: ADP, Dep: prep, Lemma: behind
# Text: that, POS: DET, Dep: det, Lemma: that
# Text: officer, POS: NOUN, Dep: pobj, Lemma: officer
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: who, POS: PRON, Dep: nsubj, Lemma: who
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: turn, POS: NOUN, Dep: pobj, Lemma: turn
# Text: moved, POS: VERB, Dep: relcl, Lemma: move
# Text: apart, POS: ADV, Dep: advmod, Lemma: apart
# Text: one, POS: NUM, Dep: nummod, Lemma: one
# Text: pace, POS: NOUN, Dep: dobj, Lemma: pace
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: These, POS: DET, Dep: det, Lemma: these
# Text: movements, POS: NOUN, Dep: nsubj, Lemma: movement
# Text: left, POS: VERB, Dep: ROOT, Lemma: leave
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: condemned, POS: VERB, Dep: amod, Lemma: condemn
# Text: man, POS: NOUN, Dep: dobj, Lemma: man
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: sergeant, POS: NOUN, Dep: conj, Lemma: sergeant
# Text: standing, POS: VERB, Dep: acl, Lemma: stand
# Text: on, POS: ADP, Dep: prep, Lemma: on
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text: ends, POS: NOUN, Dep: pobj, Lemma: end
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: same, POS: ADJ, Dep: amod, Lemma: same
# Text: plank, POS: NOUN, Dep: pobj, Lemma: plank
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: which, POS: PRON, Dep: nsubj, Lemma: which
# Text: spanned, POS: VERB, Dep: relcl, Lemma: span
# Text: three, POS: NUM, Dep: dobj, Lemma: three
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: cross, POS: ADJ, Dep: pobj, Lemma: cross
# Text: -, POS: NOUN, Dep: pobj, Lemma: -
# Text: ties, POS: NOUN, Dep: pobj, Lemma: tie
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: end, POS: NOUN, Dep: nsubj, Lemma: end
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: which, POS: PRON, Dep: pobj, Lemma: which
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: civilian, POS: NOUN, Dep: nsubj, Lemma: civilian
# Text: stood, POS: VERB, Dep: relcl, Lemma: stand
# Text: almost, POS: ADV, Dep: advmod, Lemma: almost
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: but, POS: CCONJ, Dep: cc, Lemma: but
# Text: not, POS: PART, Dep: neg, Lemma: not
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: quite, POS: ADV, Dep: conj, Lemma: quite
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: reached, POS: VERB, Dep: ROOT, Lemma: reach
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: fourth, POS: ADJ, Dep: dobj, Lemma: fourth
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: This, POS: DET, Dep: det, Lemma: this
# Text: plank, POS: NOUN, Dep: nsubjpass, Lemma: plank
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: been, POS: AUX, Dep: auxpass, Lemma: be
# Text: held, POS: VERB, Dep: ccomp, Lemma: hold
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: place, POS: NOUN, Dep: pobj, Lemma: place
# Text: by, POS: ADP, Dep: agent, Lemma: by
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: weight, POS: NOUN, Dep: pobj, Lemma: weight
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: captain, POS: NOUN, Dep: pobj, Lemma: captain
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: it, POS: PRON, Dep: nsubjpass, Lemma: it
# Text: was, POS: AUX, Dep: auxpass, Lemma: be
# Text: now, POS: ADV, Dep: advmod, Lemma: now
# Text: held, POS: VERB, Dep: ROOT, Lemma: hold
# Text: by, POS: ADP, Dep: agent, Lemma: by
# Text: that, POS: PRON, Dep: pobj, Lemma: that
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: sergeant, POS: NOUN, Dep: pobj, Lemma: sergeant
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: At, POS: ADP, Dep: prep, Lemma: at
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: signal, POS: NOUN, Dep: pobj, Lemma: signal
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: former, POS: ADJ, Dep: pobj, Lemma: former
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: latter, POS: NOUN, Dep: nsubj, Lemma: latter
# Text: would, POS: AUX, Dep: aux, Lemma: would
# Text: step, POS: VERB, Dep: ccomp, Lemma: step
# Text: aside, POS: ADV, Dep: advmod, Lemma: aside
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: plank, POS: NOUN, Dep: nsubj, Lemma: plank
# Text: would, POS: AUX, Dep: aux, Lemma: would
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: tilt, POS: VERB, Dep: ROOT, Lemma: tilt
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: condemned, POS: VERB, Dep: amod, Lemma: condemn
# Text: man, POS: NOUN, Dep: nsubj, Lemma: man
# Text: go, POS: VERB, Dep: conj, Lemma: go
# Text: down, POS: ADP, Dep: prt, Lemma: down
# Text: between, POS: ADP, Dep: prep, Lemma: between
# Text: two, POS: NUM, Dep: nummod, Lemma: two
# Text: ties, POS: NOUN, Dep: pobj, Lemma: tie
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: arrangement, POS: NOUN, Dep: nsubj, Lemma: arrangement
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: commended, POS: VERB, Dep: ROOT, Lemma: commend
# Text: itself, POS: PRON, Dep: dobj, Lemma: itself
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: judgement, POS: NOUN, Dep: pobj, Lemma: judgement
# Text: as, POS: ADP, Dep: prep, Lemma: as
# Text: simple, POS: ADJ, Dep: amod, Lemma: simple
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: effective, POS: ADJ, Dep: conj, Lemma: effective
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: His, POS: PRON, Dep: poss, Lemma: his
# Text: face, POS: NOUN, Dep: nsubjpass, Lemma: face
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: not, POS: PART, Dep: neg, Lemma: not
# Text: been, POS: AUX, Dep: auxpass, Lemma: be
# Text: covered, POS: VERB, Dep: ROOT, Lemma: cover
# Text: nor, POS: CCONJ, Dep: cc, Lemma: nor
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: eyes, POS: NOUN, Dep: nsubj, Lemma: eye
# Text: bandaged, POS: VERB, Dep: conj, Lemma: bandage
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: looked, POS: VERB, Dep: ROOT, Lemma: look
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: moment, POS: NOUN, Dep: npadvmod, Lemma: moment
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: unsteadfast, POS: ADJ, Dep: amod, Lemma: unsteadfast
# Text: footing, POS: NOUN, Dep: pobj, Lemma: footing
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: ", POS: PUNCT, Dep: punct, Lemma: "
# Text: then, POS: ADV, Dep: advmod, Lemma: then
# Text: let, POS: VERB, Dep: dep, Lemma: let
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: gaze, POS: NOUN, Dep: nsubj, Lemma: gaze
# Text: wander, POS: VERB, Dep: ccomp, Lemma: wander
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: swirling, POS: VERB, Dep: amod, Lemma: swirl
# Text: water, POS: NOUN, Dep: pobj, Lemma: water
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: stream, POS: NOUN, Dep: pobj, Lemma: stream
# Text: racing, POS: VERB, Dep: advcl, Lemma: race
# Text: madly, POS: ADV, Dep: advmod, Lemma: madly
# Text: beneath, POS: ADP, Dep: prep, Lemma: beneath
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: feet, POS: NOUN, Dep: pobj, Lemma: foot
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text: A, POS: DET, Dep: det, Lemma: a
# Text: piece, POS: NOUN, Dep: nsubj, Lemma: piece
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: dancing, POS: NOUN, Dep: compound, Lemma: dancing
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: driftwood, POS: NOUN, Dep: pobj, Lemma: driftwood
# Text: caught, POS: VERB, Dep: ROOT, Lemma: catch
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: attention, POS: NOUN, Dep: dobj, Lemma: attention
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: eyes, POS: NOUN, Dep: nsubj, Lemma: eye
# Text: followed, POS: VERB, Dep: conj, Lemma: follow
# Text: it, POS: PRON, Dep: dobj, Lemma: it
# Text: down, POS: ADP, Dep: prep, Lemma: down
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: current, POS: NOUN, Dep: pobj, Lemma: current
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: How, POS: SCONJ, Dep: advmod, Lemma: how
# Text: slowly, POS: ADV, Dep: advmod, Lemma: slowly
# Text: it, POS: PRON, Dep: nsubj, Lemma: it
# Text: appeared, POS: VERB, Dep: ROOT, Lemma: appear
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: move, POS: VERB, Dep: xcomp, Lemma: move
# Text: !, POS: PUNCT, Dep: punct, Lemma: !
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: What, POS: PRON, Dep: det, Lemma: what
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: sluggish, POS: ADJ, Dep: amod, Lemma: sluggish
# Text: stream, POS: NOUN, Dep: ROOT, Lemma: stream
# Text: !, POS: PUNCT, Dep: punct, Lemma: !
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: closed, POS: VERB, Dep: ROOT, Lemma: close
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: eyes, POS: NOUN, Dep: dobj, Lemma: eye
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: order, POS: NOUN, Dep: pobj, Lemma: order
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: fix, POS: VERB, Dep: acl, Lemma: fix
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: last, POS: ADJ, Dep: amod, Lemma: last
# Text: thoughts, POS: NOUN, Dep: dobj, Lemma: thought
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: wife, POS: NOUN, Dep: pobj, Lemma: wife
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: children, POS: NOUN, Dep: conj, Lemma: child
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: The, POS: DET, Dep: det, Lemma: the
# Text: water, POS: NOUN, Dep: nsubj, Lemma: water
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: touched, POS: VERB, Dep: acl, Lemma: touch
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: gold, POS: NOUN, Dep: pobj, Lemma: gold
# Text: by, POS: ADP, Dep: agent, Lemma: by
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: early, POS: ADJ, Dep: amod, Lemma: early
# Text: sun, POS: NOUN, Dep: pobj, Lemma: sun
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: brooding, POS: NOUN, Dep: amod, Lemma: brooding
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: mists, POS: NOUN, Dep: appos, Lemma: mist
# Text: under, POS: ADP, Dep: prep, Lemma: under
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: banks, POS: NOUN, Dep: pobj, Lemma: bank
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: some, POS: DET, Dep: det, Lemma: some
# Text: distance, POS: NOUN, Dep: pobj, Lemma: distance
# Text: down, POS: ADP, Dep: prep, Lemma: down
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: stream, POS: NOUN, Dep: pobj, Lemma: stream
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: fort, POS: NOUN, Dep: conj, Lemma: fort
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: soldiers, POS: NOUN, Dep: conj, Lemma: soldier
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: piece, POS: NOUN, Dep: conj, Lemma: piece
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: drift, POS: NOUN, Dep: pobj, Lemma: drift
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: all, POS: PRON, Dep: nsubj, Lemma: all
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: distracted, POS: VERB, Dep: ROOT, Lemma: distract
# Text: him, POS: PRON, Dep: dobj, Lemma: he
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: And, POS: CCONJ, Dep: cc, Lemma: and
# Text: now, POS: ADV, Dep: advmod, Lemma: now
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: became, POS: VERB, Dep: ROOT, Lemma: become
# Text: conscious, POS: ADJ, Dep: acomp, Lemma: conscious
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: new, POS: ADJ, Dep: amod, Lemma: new
# ...
# Text: twice, POS: ADV, Dep: advmod, Lemma: twice
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: again, POS: ADV, Dep: conj, Lemma: again
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: distinctly, POS: ADV, Dep: advmod, Lemma: distinctly
# Text: heard, POS: VERB, Dep: ROOT, Lemma: hear
# Text: whispers, POS: NOUN, Dep: dobj, Lemma: whisper
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: an, POS: DET, Dep: det, Lemma: an
# Text: unknown, POS: ADJ, Dep: amod, Lemma: unknown
# Text: tongue, POS: NOUN, Dep: pobj, Lemma: tongue
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: His, POS: PRON, Dep: poss, Lemma: his
# Text: neck, POS: NOUN, Dep: nsubj, Lemma: neck
# Text: was, POS: AUX, Dep: ROOT, Lemma: be
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: pain, POS: NOUN, Dep: pobj, Lemma: pain
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: lifting, POS: VERB, Dep: conj, Lemma: lift
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: hand, POS: NOUN, Dep: dobj, Lemma: hand
# Text: to, POS: ADP, Dep: prep, Lemma: to
# Text: it, POS: PRON, Dep: pobj, Lemma: it
# Text: found, POS: VERB, Dep: conj, Lemma: find
# Text: it, POS: PRON, Dep: nsubj, Lemma: it
# Text: horribly, POS: ADV, Dep: advmod, Lemma: horribly
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: swollen, POS: ADJ, Dep: ccomp, Lemma: swollen
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: knew, POS: VERB, Dep: ROOT, Lemma: know
# Text: that, POS: SCONJ, Dep: mark, Lemma: that
# Text: it, POS: PRON, Dep: nsubj, Lemma: it
# Text: had, POS: VERB, Dep: ccomp, Lemma: have
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: circle, POS: NOUN, Dep: dobj, Lemma: circle
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: black, POS: NOUN, Dep: pobj, Lemma: black
# Text: where, POS: SCONJ, Dep: advmod, Lemma: where
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: rope, POS: NOUN, Dep: nsubj, Lemma: rope
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: bruised, POS: VERB, Dep: relcl, Lemma: bruise
# Text: it, POS: PRON, Dep: dobj, Lemma: it
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: His, POS: PRON, Dep: poss, Lemma: his
# Text: eyes, POS: NOUN, Dep: nsubj, Lemma: eye
# Text: felt, POS: VERB, Dep: ccomp, Lemma: feel
# Text: congested, POS: VERB, Dep: acomp, Lemma: congest
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: could, POS: AUX, Dep: aux, Lemma: could
# Text: no, POS: ADV, Dep: neg, Lemma: no
# Text: longer, POS: ADV, Dep: advmod, Lemma: long
# Text: close, POS: VERB, Dep: ROOT, Lemma: close
# Text: them, POS: PRON, Dep: dobj, Lemma: they
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: His, POS: PRON, Dep: poss, Lemma: his
# Text: tongue, POS: NOUN, Dep: nsubj, Lemma: tongue
# Text: was, POS: AUX, Dep: ccomp, Lemma: be
# Text: swollen, POS: ADJ, Dep: acomp, Lemma: swollen
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: thirst, POS: ADV, Dep: pobj, Lemma: thirst
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: relieved, POS: VERB, Dep: ROOT, Lemma: relieve
# Text: its, POS: PRON, Dep: poss, Lemma: its
# Text: fever, POS: NOUN, Dep: dobj, Lemma: fever
# Text: by, POS: ADP, Dep: prep, Lemma: by
# Text: thrusting, POS: VERB, Dep: pcomp, Lemma: thrust
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: it, POS: PRON, Dep: dobj, Lemma: it
# Text: forward, POS: ADV, Dep: advmod, Lemma: forward
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: between, POS: ADP, Dep: prep, Lemma: between
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: teeth, POS: NOUN, Dep: pobj, Lemma: tooth
# Text: into, POS: ADP, Dep: prep, Lemma: into
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: cold, POS: ADJ, Dep: amod, Lemma: cold
# Text: air, POS: NOUN, Dep: pobj, Lemma: air
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: How, POS: SCONJ, Dep: advmod, Lemma: how
# Text: softly, POS: ADV, Dep: advmod, Lemma: softly
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: turf, POS: NOUN, Dep: nsubj, Lemma: turf
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: carpeted, POS: VERB, Dep: ccomp, Lemma: carpet
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: untraveled, POS: ADJ, Dep: amod, Lemma: untraveled
# Text: avenue, POS: NOUN, Dep: dobj, Lemma: avenue
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: could, POS: AUX, Dep: aux, Lemma: could
# Text: no, POS: ADV, Dep: neg, Lemma: no
# Text: longer, POS: ADV, Dep: advmod, Lemma: long
# Text: feel, POS: VERB, Dep: ROOT, Lemma: feel
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: roadway, POS: NOUN, Dep: dobj, Lemma: roadway
# Text: beneath, POS: ADP, Dep: prep, Lemma: beneath
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: feet, POS: NOUN, Dep: pobj, Lemma: foot
# Text: !, POS: PUNCT, Dep: punct, Lemma: !
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: Doubtless, POS: PROPN, Dep: nsubj, Lemma: Doubtless
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: despite, POS: SCONJ, Dep: prep, Lemma: despite
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: suffering, POS: NOUN, Dep: pobj, Lemma: suffering
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: had, POS: AUX, Dep: aux, Lemma: have
# Text: fallen, POS: VERB, Dep: ccomp, Lemma: fall
# Text: asleep, POS: ADJ, Dep: oprd, Lemma: asleep
# Text: while, POS: SCONJ, Dep: mark, Lemma: while
# Text: walking, POS: VERB, Dep: advcl, Lemma: walk
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: for, POS: ADP, Dep: prep, Lemma: for
# Text: now, POS: ADV, Dep: pcomp, Lemma: now
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: sees, POS: VERB, Dep: advcl, Lemma: see
# Text: another, POS: DET, Dep: det, Lemma: another
# Text: scene, POS: NOUN, Dep: dobj, Lemma: scene
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: perhaps, POS: ADV, Dep: advmod, Lemma: perhaps
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: has, POS: AUX, Dep: aux, Lemma: have
# Text: merely, POS: ADV, Dep: advmod, Lemma: merely
# Text: recovered, POS: VERB, Dep: ROOT, Lemma: recover
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: a, POS: DET, Dep: det, Lemma: a
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: delirium, POS: NOUN, Dep: pobj, Lemma: delirium
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: stands, POS: VERB, Dep: ROOT, Lemma: stand
# Text: at, POS: ADP, Dep: prep, Lemma: at
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: gate, POS: NOUN, Dep: pobj, Lemma: gate
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: own, POS: ADJ, Dep: amod, Lemma: own
# Text: home, POS: NOUN, Dep: pobj, Lemma: home
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: All, POS: PRON, Dep: nsubj, Lemma: all
# Text: is, POS: AUX, Dep: ROOT, Lemma: be
# Text: as, POS: SCONJ, Dep: mark, Lemma: as
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: left, POS: VERB, Dep: advcl, Lemma: leave
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: it, POS: PRON, Dep: dobj, Lemma: it
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: all, POS: PRON, Dep: advmod, Lemma: all
# Text: bright, POS: ADJ, Dep: conj, Lemma: bright
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: beautiful, POS: ADJ, Dep: conj, Lemma: beautiful
# Text: in, POS: ADP, Dep: prep, Lemma: in
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: morning, POS: NOUN, Dep: compound, Lemma: morning
# Text: sunshine, POS: NOUN, Dep: pobj, Lemma: sunshine
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: must, POS: AUX, Dep: aux, Lemma: must
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: have, POS: AUX, Dep: aux, Lemma: have
# Text: traveled, POS: VERB, Dep: ROOT, Lemma: travel
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: entire, POS: ADJ, Dep: amod, Lemma: entire
# Text: night, POS: NOUN, Dep: dobj, Lemma: night
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: As, POS: SCONJ, Dep: mark, Lemma: as
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: pushes, POS: AUX, Dep: aux, Lemma: pushes
# Text: open, POS: VERB, Dep: advcl, Lemma: open
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: gate, POS: NOUN, Dep: dobj, Lemma: gate
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: passes, POS: VERB, Dep: conj, Lemma: pass
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: up, POS: ADP, Dep: prt, Lemma: up
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: wide, POS: ADJ, Dep: amod, Lemma: wide
# Text: white, POS: ADJ, Dep: amod, Lemma: white
# Text: walk, POS: NOUN, Dep: dobj, Lemma: walk
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: sees, POS: VERB, Dep: ccomp, Lemma: see
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: flutter, POS: NOUN, Dep: dobj, Lemma: flutter
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: female, POS: ADJ, Dep: amod, Lemma: female
# Text: garments, POS: NOUN, Dep: pobj, Lemma: garment
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: wife, POS: NOUN, Dep: nsubj, Lemma: wife
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: looking, POS: VERB, Dep: acl, Lemma: look
# Text: fresh, POS: ADJ, Dep: acomp, Lemma: fresh
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: cool, POS: ADJ, Dep: conj, Lemma: cool
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: sweet, POS: ADJ, Dep: conj, Lemma: sweet
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: steps, POS: VERB, Dep: ROOT, Lemma: step
# Text: down, POS: ADP, Dep: prt, Lemma: down
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: veranda, POS: NOUN, Dep: pobj, Lemma: veranda
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: meet, POS: VERB, Dep: advcl, Lemma: meet
# Text: him, POS: PRON, Dep: dobj, Lemma: he
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: At, POS: ADP, Dep: ROOT, Lemma: at
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: bottom, POS: NOUN, Dep: pobj, Lemma: bottom
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: steps, POS: NOUN, Dep: pobj, Lemma: step
# Text: she, POS: PRON, Dep: nsubj, Lemma: she
# Text: stands, POS: VERB, Dep: relcl, Lemma: stand
# Text: waiting, POS: VERB, Dep: acl, Lemma: wait
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: with, POS: ADP, Dep: conj, Lemma: with
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: smile, POS: NOUN, Dep: pobj, Lemma: smile
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: ineffable, POS: ADJ, Dep: amod, Lemma: ineffable
# Text: joy, POS: NOUN, Dep: pobj, Lemma: joy
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: an, POS: DET, Dep: det, Lemma: an
# Text: attitude, POS: NOUN, Dep: appos, Lemma: attitude
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: matchless, POS: NOUN, Dep: compound, Lemma: matchless
# Text: grace, POS: NOUN, Dep: pobj, Lemma: grace
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: dignity, POS: NOUN, Dep: conj, Lemma: dignity
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: Ah, POS: INTJ, Dep: intj, Lemma: ah
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: how, POS: SCONJ, Dep: advmod, Lemma: how
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: beautiful, POS: ADJ, Dep: acomp, Lemma: beautiful
# Text: she, POS: PRON, Dep: nsubj, Lemma: she
# Text: is, POS: AUX, Dep: ROOT, Lemma: be
# Text: !, POS: PUNCT, Dep: punct, Lemma: !
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: He, POS: PRON, Dep: nsubj, Lemma: he
# Text: springs, POS: VERB, Dep: ROOT, Lemma: spring
# Text: forwards, POS: ADV, Dep: advmod, Lemma: forwards
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: extended, POS: ADJ, Dep: amod, Lemma: extended
# Text: arms, POS: NOUN, Dep: pobj, Lemma: arm
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:  , POS: SPACE, Dep: dep, Lemma:
# Text: As, POS: SCONJ, Dep: mark, Lemma: as
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: is, POS: AUX, Dep: advcl, Lemma: be
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: about, POS: ADJ, Dep: acomp, Lemma: about
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: clasp, POS: VERB, Dep: xcomp, Lemma: clasp
# Text: her, POS: PRON, Dep: dobj, Lemma: she
# Text: he, POS: PRON, Dep: nsubj, Lemma: he
# Text: feels, POS: VERB, Dep: ccomp, Lemma: feel
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: stunning, POS: ADJ, Dep: amod, Lemma: stunning
# Text: blow, POS: NOUN, Dep: dobj, Lemma: blow
# Text: upon, POS: SCONJ, Dep: prep, Lemma: upon
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: back, POS: NOUN, Dep: pobj, Lemma: back
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: neck, POS: NOUN, Dep: pobj, Lemma: neck
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: blinding, POS: VERB, Dep: amod, Lemma: blind
# Text: white, POS: ADJ, Dep: amod, Lemma: white
# Text: light, POS: NOUN, Dep: nsubj, Lemma: light
# Text: blazes, POS: NOUN, Dep: conj, Lemma: blaze
# Text: all, POS: ADV, Dep: advmod, Lemma: all
# Text: about, POS: ADP, Dep: prep, Lemma: about
# Text: him, POS: PRON, Dep: pobj, Lemma: he
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: sound, POS: NOUN, Dep: pobj, Lemma: sound
# Text: like, POS: ADP, Dep: prep, Lemma: like
# Text: the, POS: DET, Dep: det, Lemma: the
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: shock, POS: NOUN, Dep: pobj, Lemma: shock
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: cannon, POS: NOUN, Dep: pobj, Lemma: cannon
# Text: --, POS: PUNCT, Dep: punct, Lemma: --
# Text: then, POS: ADV, Dep: advmod, Lemma: then
# Text: all, POS: PRON, Dep: nsubj, Lemma: all
# Text: is, POS: AUX, Dep: ROOT, Lemma: be
# Text: darkness, POS: NOUN, Dep: attr, Lemma: darkness
# Text: and, POS: CCONJ, Dep: cc, Lemma: and
# Text: silence, POS: NOUN, Dep: conj, Lemma: silence
# Text: !, POS: PUNCT, Dep: punct, Lemma: !
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:
#
#
# Text: Peyton, POS: PROPN, Dep: compound, Lemma: Peyton
# Text: Farquhar, POS: PROPN, Dep: nsubj, Lemma: Farquhar
# Text: was, POS: AUX, Dep: ccomp, Lemma: be
# Text: dead, POS: ADJ, Dep: acomp, Lemma: dead
# Text: ;, POS: PUNCT, Dep: punct, Lemma: ;
# Text: his, POS: PRON, Dep: poss, Lemma: his
# Text: body, POS: NOUN, Dep: nsubj, Lemma: body
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: with, POS: ADP, Dep: prep, Lemma: with
# Text: a, POS: DET, Dep: det, Lemma: a
# Text: broken, POS: ADJ, Dep: amod, Lemma: broken
# Text: neck, POS: NOUN, Dep: pobj, Lemma: neck
# Text: ,, POS: PUNCT, Dep: punct, Lemma: ,
# Text: swung, POS: VERB, Dep: ROOT, Lemma: swing
# Text: gently, POS: ADV, Dep: advmod, Lemma: gently
# Text:
# , POS: SPACE, Dep: dep, Lemma:
#
# Text: from, POS: ADP, Dep: prep, Lemma: from
# Text: side, POS: NOUN, Dep: pobj, Lemma: side
# Text: to, POS: PART, Dep: aux, Lemma: to
# Text: side, POS: VERB, Dep: advcl, Lemma: side
# Text: beneath, POS: ADP, Dep: prep, Lemma: beneath
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: timbers, POS: NOUN, Dep: pobj, Lemma: timber
# Text: of, POS: ADP, Dep: prep, Lemma: of
# Text: the, POS: DET, Dep: det, Lemma: the
# Text: Owl, POS: PROPN, Dep: compound, Lemma: Owl
# Text: Creek, POS: PROPN, Dep: compound, Lemma: Creek
# Text: bridge, POS: NOUN, Dep: pobj, Lemma: bridge
# Text: ., POS: PUNCT, Dep: punct, Lemma: .
# Text:
#
# , POS: SPACE, Dep: dep, Lemma:

# %% [markdown]
# 6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text.

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

pattern = [{"LOWER": "swimming"}, {"LOWER": "vigorously"}]
matcher.add("Swimming", [pattern])

# Find matches in the doc
found_matches = matcher(doc)

print(found_matches)
# Out:
# []

# %% [markdown]
# 7. Print the text surrounding each found match.

# %%
# Print context around each match
for match_id, start, end in matches:
    span = doc[start:end]
    context_start = max(start - 3, 0)
    context_end = min(end + 3, len(doc))
    context = doc[context_start:context_end]
    print(f"Match: '{span.text}'")
    print(f"Context: '...{context.text}...'\n")
